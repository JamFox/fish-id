# %%
from ultralytics import YOLO

# %%
# global vars
home = '/home/karl/'

# %%
# pass any model type from n, s, m, l or x if choosing pretrained defaults
#model = YOLO('yolov8m.pt')
# or use custom model, if trained before
#model = YOLO('runs/detect/train4/weights/best.pt')
model = YOLO('runs/detect/train5/weights/best.pt')

# %%
# variables for training
custom_data = home + 'fish-dataset1/data.yaml'
epochs = 25
# train model
model.train(data=custom_data,epochs=epochs)
model.val()

# %%
# variables for training
custom_data = home + 'fish-dataset2/data.yaml'
epochs = 25
# train model
model.train(data=custom_data,epochs=epochs)
model.val()
# Out:
# Ultralytics YOLOv8.0.54 🚀 Python-3.10.5 torch-1.12.1 CUDA:0 (NVIDIA GeForce RTX 3080 Ti, 12046MiB)
# ...

# %%
# variables for training
custom_data = home + 'fish-dataset3/data.yaml'
epochs = 25
# train model
model = YOLO('runs/detect/train7/weights/best.pt')
model.train(data=custom_data,epochs=epochs)
model.val()
# Out:
# Ultralytics YOLOv8.0.54 🚀 Python-3.10.5 torch-1.12.1 CUDA:0 (NVIDIA GeForce RTX 3080 Ti, 12046MiB)
# ...
